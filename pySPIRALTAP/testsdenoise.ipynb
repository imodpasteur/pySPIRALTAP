# %%
# %matplotlib inline
import denoise_bound
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
np.random.seed(314)

# %%
X=np.asarray(Image.open('cameraman.pgm'))
X=X/255.
Bobs=X+2e-2*np.random.randn(*X.shape)

# %%
plt.figure(figsize=(18,10))
plt.subplot(121)
plt.imshow(X)
plt.subplot(122)
plt.imshow(Bobs)

# %%
denoise_bound.denoise_bound(Bobs,0.02,-np.inf,np.inf)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-c352b951121a> in <module>()
# ----> 1 denoise_bound.denoise_bound(Bobs,0.02,-np.inf,np.inf)
#
# TypeError: denoise_bound() takes exactly 5 arguments (4 given)
